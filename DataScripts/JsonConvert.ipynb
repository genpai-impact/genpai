# %%
import pandas as pd
import numpy as np
import json

data = pd.read_excel("初版卡牌导出.xlsx")

data
# Out:
#       CardType  CardID CardName_zh           CardName   CardInfo  HP  ATK  \
# 0    charaCard     100        刻晴 A           Keqing_A   My Waifu  12    5
# 1    charaCard     101        胡桃 A            Hutao_A   My Waifu  10    6
# 2    charaCard     102        刻晴 B           Keqing_B   My Waifu  12    5
# 3    charaCard     103        胡桃 B            Hutao_B   My Waifu  10    6
# 4  monsterCard     200         丘丘人          Hilichurl  Your Wife  11    3
# 5  monsterCard     201       打手丘丘人  Hilichurl Fighter  Your Wife   7    5
# 6  monsterCard     202       史莱姆·水        Hydro Slime  Your Wife  10    2
# 7  monsterCard     203       史莱姆·火         Pyro Slime  Your Wife   7    5
# 8  monsterCard     204       史莱姆·冰         Cryo Slime  Your Wife   8    4
# 9  monsterCard     205       史莱姆·雷      Electro Slime  Your Wife   8    4
#
#   ATKElement SelfElement  ChargeInfo
# 0          无           无         3.0
# 1          无           无         3.0
# 2          无           无         3.0
# 3          无           无         3.0
# 4          无           无         NaN
# 5          无           无         NaN
# 6          水           水         NaN
# 7          火           火         NaN
# 8          冰           冰         NaN
# 9          雷           雷         NaN

# %%
json_list = []

for _,card in data.iterrows():
    card_dict = {}
    card_dict["cardID"] = card.CardID
    card_dict["cardType"] = card.CardType
    card_dict["cardName"] = card.CardName
    card_dict["cardName_ZH"] = card.CardName_zh
    card_dict["cardInfo"] = card.CardInfo.split("\n")
    
    if card.CardType != "spellCard":
        unitinfo_dict = {}
        unitinfo_dict["HP"] = card.HP
        unitinfo_dict["ATK"] = card.ATK
        unitinfo_dict["ATKElement"] = card.ATKElement
        unitinfo_dict["selfElement"] = card.SelfElement
        card_dict["UnitInfo"] = unitinfo_dict
        if card.CardType == "charaCard":
            card_dict["CardCharge"] = card.ChargeInfo
    json_list.append(card_dict)

json_dict = {}
json_dict["cardData"] = json_list

data_json = json.dumps(json_dict)

print(json_list)

with open("data.json","w",encoding=utf-8) as f_w:
    f_w.write(data_json)
# Out:
